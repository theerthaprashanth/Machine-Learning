# %%
import numpy

# %%
actual=numpy.random.binomial(1,0.9,size=1000)
predicted=numpy.random.binomial(1,0.9,size=1000)

# %%
from sklearn import metrics

# %%
confusion_matrix = metrics.confusion_matrix(actual, predicted)

# %%
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])

# %%
cm_display

# %%
import matplotlib.pyplot as plt

# %%
cm_display.plot()
plt.show()

# %% [markdown]
# 1️⃣ Actual 0, Predicted 0 → 10
#
# ➡️ These are correct predictions.
# Model said “0”, and it was really “0”.
#
# 2️⃣ Actual 0, Predicted 1 → 94
#
# ➡️ These are wrong predictions.
# Model said “1”, but the truth was “0”.
#
# 3️⃣ Actual 1, Predicted 0 → 95
#
# ➡️ These are also wrong predictions.
# Model said “0”, but the truth was “1”.
#
# 4️⃣ Actual 1, Predicted 1 → 801
#
# ➡️ These are correct predictions.
# Model said “1”, and it was really “1”.

# %%
Accuracy = metrics.accuracy_score(actual, predicted)
Accuracy
# Out:
# 0.811

# %%
Precision = metrics.precision_score(actual, predicted)
Precision
# Out:
# 0.8949720670391061

# %%
Specificity = metrics.recall_score(actual, predicted, pos_label=0)
Specificity
# Out:
# 0.09615384615384616

# %%
F1_score = metrics.f1_score(actual, predicted)
F1_score
# Out:
# 0.8944723618090452

# %%
Sensitivity_recall = metrics.recall_score(actual, predicted)
Sensitivity_recall
# Out:
# 0.8939732142857143

# %%
#metrics
print({"Accuracy":Accuracy,"Precision":Precision,"Sensitivity_recall":Sensitivity_recall,"Specificity":Specificity,"F1_score":F1_score})
# Out:
# {'Accuracy': 0.811, 'Precision': 0.8949720670391061, 'Sensitivity_recall': 0.8939732142857143, 'Specificity': 0.09615384615384616, 'F1_score': 0.8944723618090452}
